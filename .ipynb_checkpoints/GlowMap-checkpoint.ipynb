# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
#TODO:
#Make Big nodes have a the sum value displayed

# %%
n = 51
nodes = range(n)
edges = [
    (47,0),(47,45),(47,37),(47,42),
    (0, 1), (0, 2), (0,5), (0,21), (0,22), (0,29),(0,1),
    (2, 44), (2, 3), (2,4), (5, 6), (5,8), (5,14),(29,30),(29,31),(29,32),(29,33),(29,34),(29,35),(29,36),
    (6,7), (8,9),(8,10),(8,11),(8,12),(8,13),(14,15),(14,16),(14,17),(14,18),(14,19),(14,20),
    (45,23),(45,25),(45,24),(45,26),(45,27),(27,28),(45,46),
    (24, 48),(24, 49), (24, 50),
    (27, 51),
]

# 1000 - expert
# 700 - Experimented with it
# 500 - Have encountered different errors, comfortable with it
# 300 - Can work with it and use it
# 100 - Understood the fundamentals
# 50 - Watched a tutorial
# 1 - default

attributes = {
    
    47:{'name':'Total', 'category':'1', 'size': 1},
        0:{'name':'Frontend', 'category':'1', 'size': 1},
            1:{'name':'Webpack', 'category':'1', 'size':1},
            2:{'name':'CSS', 'category':'1', 'size':1},
                44:{'name':'SASS', 'category':'1', 'size': 700},
                3:{'name':'Tailwind', 'category':'1', 'size': 50},
                4:{'name':'CSS Animations', 'category':'1', 'size': 200},
            29:{'name':'Firebase', 'category':'1', 'size':150},
                30:{'name':'Firebase \nFile Storage', 'category':'1', 'size': 100},
                31:{'name':'Firebase Security Rules', 'category':'1', 'size': 200},
                32:{'name':'Firestore Cloud functions', 'category':'1', 'size': 50},
                33:{'name':'Firebase Authentication', 'category':'1', 'size': 500},
                34:{'name':'File Emulator Suite', 'category':'1', 'size': 50},
                35:{'name':'File Data Modeling', 'category':'1', 'size': 50},
                36:{'name':'Firebase Hosting', 'category':'1', 'size': 200},
            52:{'name':'Frontend Frameworks', 'category':'1', 'size': 200},
                53:{'name':'Angular', 'category':'1', 'size': 200},
                54:{'name':'Vue', 'category':'1', 'size': 200},
                5:{'name':'React', 'category':'1', 'size':1},
                    6:{'name':'React Frameworks', 'category':'1', 'size':1},
                        7:{'name':'Next.js', 'category':'1', 'size': 200},
                    8:{'name':'React Hooks', 'category':'1', 'size':1},
                        9:{'name':'UseCallback', 'category':'1', 'size':100},
                        10:{'name':'UseState', 'category':'1', 'size': 600},
                        11:{'name':'UseEffect', 'category':'1', 'size': 400},
                        12:{'name':'UseRef', 'category':'1', 'size': 100},
                        13:{'name':'CustomHooks', 'category':'1', 'size': 150},
                    14:{'name':'Advanced Concepts', 'category':'1', 'size': 1},
                        15:{'name':'React query', 'category':'1', 'size': 100},
                        16:{'name':'Mutations', 'category':'1', 'size': 1},
                        17:{'name':'Suspense', 'category':'1', 'size': 1},
                        18:{'name':'TRPC', 'category':'1', 'size': 1},
                        19:{'name':'State Machines', 'category':'1', 'size': 1},
                        20:{'name':'Prisma', 'category':'1', 'size': 1},
            21:{'name':'Typescript', 'category':'1', 'size': 400},
            22:{'name':'Jquery', 'category':'1', 'size': 100},
        45:{'name':'General', 'category':'1', 'size':1},
            46:{'name':'Algorithms', 'category':'1', 'size': 150},
            23:{'name':'Middleware', 'category':'1', 'size': 50},
            24:{'name':'Github', 'category':'1', 'size': 1},
                48:{'name':'Branches', 'category':'1', 'size': 100},
                49:{'name':'Merging', 'category':'1', 'size': 100},
                50:{'name':'Basics', 'category':'1', 'size': 500},
            25:{'name':'Debugger', 'category':'1', 'size': 50},
            26:{'name':'Testing', 'category':'1', 'size': 50},
            27:{'name':'Search', 'category':'1', 'size': 1},
                28:{'name':'Algolia Search', 'category':'1', 'size': 25},
                51:{'name':'Search Basics', 'category':'1', 'size': 25},

        37:{'name':'Deployment', 'category':'1', 'size': 1},
            38:{'name':'Advanced', 'category':'1', 'size':150},
                39:{'name':'Docker', 'category':'1', 'size':150},
                40:{'name':'Kubernetes', 'category':'1', 'size':150},
                41:{'name':'Jenkins', 'category':'1', 'size':150},
        42:{'name':'Backend', 'category':'1', 'size':20},
            43:{'name':'Python', 'category':'1', 'size':20},

 }

# %%
G = nx.DiGraph()

G.add_nodes_from(nodes)
G.add_edges_from(edges)
nx.set_node_attributes(G, attributes)

# %%
def get_node_size(node, G):
    neighb = list(G.neighbors(node))
    if len(neighb)==0:
        return attributes[node]['size']
    else:
        return sum([attributes[n]['size'] for n in neighb])
    
def update_sizes(attributes):
    l = [x[0] for x in sorted(G.out_degree, key=lambda x: x[1], reverse=True)]
    for node in l:
        attributes[node]['size'] = get_node_size(node, G)
    return attributes

# %%
attributes = update_sizes(attributes)
attributes = update_sizes(attributes)
attributes = update_sizes(attributes)
nx.set_node_attributes(G, attributes)

# %%
#pos = nx.planar_layout(G ) #k=1, seed=8
G1 = nx.Graph()
G1.add_nodes_from(nodes)
G1.add_edges_from(edges)
pos1 = nx.planar_layout(G1) #, k=0.3

pos1[47] = np.array([0, 0])
pos1[0] = np.array([0, 0.1])
pos1[45] = np.array([-0.3, 0.0])
pos1[37] = np.array([0.3, 0.0])
pos1[42] = np.array([0, -0.1])

pos1[29] = np.array([-0.2, 0.1])
pos1[52] = np.array([0.2, 0.1])


color_palette = {'1':'red', '2':'blue'}
color = [color_palette[node[1]['category']] for node in G.nodes(data=True)]
size = [node[1]['size'] for node in G.nodes(data=True)]
name = {i:attributes[i]['name'] for i in range(n)}

fig = plt.figure(figsize=(20, 15))
nx.draw_networkx_nodes(G, pos=pos1, node_color=color, node_size=size, alpha=0.5)
nx.draw_networkx_edges(G, pos=pos1, connectionstyle="arc3,rad=0.1")
nx.draw_networkx_labels(G, pos=pos1, labels=name)
plt.show()

# %%
print(pos)
# Out:
# {0: array([-0.08535533,  0.06066433]), 1: array([-0.38624778,  0.82127628]), 2: array([ 0.57823669, -0.25213172]), 3: array([0.97762028, 0.09363462]), 4: array([ 0.06941409, -0.97701701]), 5: array([-0.12504426,  0.38009028]), 6: array([-0.21317661,  0.72154339]), 7: array([-0.2653553 ,  0.97756341]), 8: array([-0.22181213,  0.20741147]), 9: array([-0.96467907, -0.08722233]), 10: array([-0.5435795,  0.8822537]), 11: array([-0.05932954,  0.96004232]), 12: array([-0.30317843, -0.95836896]), 13: array([0.6012096 , 0.73293807]), 14: array([0.03480213, 0.10912317]), 15: array([ 0.97544339, -0.19100618]), 16: array([-0.70770909,  0.73689275]), 17: array([0.2150686 , 0.96678033]), 18: array([0.73783251, 0.65269138]), 19: array([-0.67139906, -0.50496811]), 20: array([-0.29984501, -0.8496454 ]), 21: array([ 0.36763458, -0.81459204]), 22: array([-0.80527189,  0.58953561]), 23: array([ 0.83584173, -0.63418777]), 24: array([0.53673496, 0.04100346]), 25: array([-0.96972525, -0.26009984]), 26: arr
# ...
